# %%
import pandas as pd
import numpy as np

# %%
M = pd.read_csv("Movie Reviews.csv", index_col='Name')

# %%
M.head()
# Out:
#                      American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Mike                             NaN                                    NaN
# HJ SONG                          NaN                                      2
# Ryan Hansen                      NaN                                      3
# Olumuyiwa Durojaiye              NaN                                    NaN
# Charlie                          NaN                                      2
#
#                      Guardians of the Galaxy  The Lego Movie  The Hobbit  \
# Name
# Mike                                       5             NaN           4
# HJ SONG                                    3               4           4
# Ryan Hansen                                4               3           5
# Olumuyiwa Durojaiye                      NaN             NaN         NaN
# Charlie                                    3             NaN           3
#
# ...

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
M.shape
# Out:
# (31, 16)

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %% [markdown]
# ###Question 1:  What movie is most Similar to 'The fault in our stars'

# %%
recs = get_recs('The Fault in Our Stars', M, 10)

# %%
recs[:1]
# Out:
# [('Transformers', 0.46673568990261)]

# %% [markdown]
# ###Question 2:  Which movie(s) would you most like to see, based on your classmates experience?

# %%
#the movies which I've seen
my_ratings = M.ix['Aswini kumar'].dropna()

# %%
#the movies which I've rated the highest
my_ratings.sort(ascending=False)
max=my_ratings.values[0]
fav_movies=my_ratings[my_ratings==max]

# %%
fav_movies
# Out:
# Interstellar               5
# Big Hero 6                 5
# Guardians of the Galaxy    5
# Name: Aswini kumar, dtype: float64

# %%
#based on my classmates experience the movie I would like to see 
for i in range(len(fav_movies)):
         recs = get_recs(fav_movies.index[i], M, 10)
         print recs[:1]
# Out:
# [('The Lego Movie', 0.46574538914196745)]
# [('Transformers', 0.45293471081198539)]
# [('The Hunger Games: Mockingjay - Part 1', 0.67851374100065553)]

# %% [markdown]
# ###Question 3: Bonus Question...  For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews?

# %%
df1=M.fillna(0)
df1[df1 != 0] = 1
df1
# Out:
#                      American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Mike                               0                                      0
# HJ SONG                            0                                      1
# Ryan Hansen                        0                                      1
# Olumuyiwa Durojaiye                0                                      0
# Charlie                            0                                      1
# Sina Tuy                           0                                      1
# Pavithra Shetty                    0                                      1
# Sara Collins                       0                                      1
# Jonathan Doll                      0                                      1
# saikiran reddy                     1                                      1
# Aishwarya reddy                    0                                      1
# ...

# %%
co_occurence = df1.T.dot(df1) 
co_occurence
# Out:
#                                        American Sniper  \
# American Sniper                                     13
# The Hunger Games: Mockingjay - Part 1                7
# Guardians of the Galaxy                              9
# The Lego Movie                                       4
# The Hobbit                                           8
# Transformers                                         7
# Malificent                                           3
# Big Hero 6                                           3
# Godzilla                                             6
# Interstellar                                         9
# How to Train your Dragon 2                           6
# Gone Girl                                            7
# Divergent                                            6
# The Fault in Our Stars                               2
# Unbroken                                             1
# 300: Rise of an Empire                              10
#
# ...

# %%
my_movie_ratings =M.ix['Aswini kumar'].fillna(0)

# %%
my_movie_ratings
# Out:
# American Sniper                          4
# The Hunger Games: Mockingjay - Part 1    4
# Guardians of the Galaxy                  5
# The Lego Movie                           0
# The Hobbit                               0
# Transformers                             0
# Malificent                               0
# Big Hero 6                               5
# Godzilla                                 3
# Interstellar                             5
# How to Train your Dragon 2               4
# Gone Girl                                0
# Divergent                                0
# The Fault in Our Stars                   0
# Unbroken                                 0
# 300: Rise of an Empire                   4
# Name: Aswini kumar, dtype: float64

# %%
my_predicted_ratings = co_occurence.dot(my_movie_ratings)
my_predicted_ratings
# Out:
# American Sniper                          267
# The Hunger Games: Mockingjay - Part 1    459
# Guardians of the Galaxy                  484
# The Lego Movie                           312
# The Hobbit                               427
# Transformers                             475
# Malificent                               239
# Big Hero 6                               212
# Godzilla                                 392
# Interstellar                             410
# How to Train your Dragon 2               424
# Gone Girl                                252
# Divergent                                268
# The Fault in Our Stars                   183
# Unbroken                                  89
# 300: Rise of an Empire                   504
# dtype: float64
